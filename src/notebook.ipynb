# %%
import numpy as np
import torch

# %%
from FactorizePhys.FSAM_class import FSAM

# %%
model = FSAM({'input_channels': 3, 'align_channels': 8})

# %%
dim = (16, 3, 7, 7)
x = np.arange(np.prod(dim)).reshape(dim).astype(np.double)
x = torch.from_numpy(x)

# %%
model.ξ_pre(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 2
#       1 x = torch.from_numpy(x)
# ----> 2 model.ξ_pre(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
# ...

# %%
FeatureExtractor = nn.Sequential(
    nn.ConvBlock3D(inCh, nf[0], [3, 3, 3], [1, 1, 1], [1, 1, 1]),  #B, nf[0], 160, 72, 72
    nn.ConvBlock3D(nf[0], nf[1], [3, 3, 3], [1, 2, 2], [1, 0, 0]), #B, nf[1], 160, 35, 35
    nn.ConvBlock3D(nf[1], nf[1], [3, 3, 3], [1, 1, 1], [1, 0, 0]), #B, nf[1], 160, 33, 33
    nn.Dropout3d(p=dropout_rate),

    nn.ConvBlock3D(nf[1], nf[1], [3, 3, 3], [1, 1, 1], [1, 0, 0]), #B, nf[1], 160, 31, 31
    nn.ConvBlock3D(nf[1], nf[2], [3, 3, 3], [1, 2, 2], [1, 0, 0]), #B, nf[2], 160, 15, 15
    nn.ConvBlock3D(nf[2], nf[2], [3, 3, 3], [1, 1, 1], [1, 0, 0]), #B, nf[2], 160, 13, 13
    nn.Dropout3d(p=dropout_rate),
)
# Out:
# torch.float64

# %%
from torch import nn

nn.Conv3d(16, 8, (1, 1, 1), dtype=torch.double)(x).shape
# Out:
# torch.Size([8, 3, 7, 7])

# %%
x = x.view(B * self.S, D, N)
# Out:
# numpy.float64

# %%
l = [1, 2, 3]
x = [4, 5, 6]
l.append(x)

# %%
l
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
from utils import *

# %%
getsize('../data/UBFC-rPPG_2')
# Out:
# '0.0 B'

# %%
# Out:
# ['subject1',
#  'subject10',
#  'subject11',
#  'subject12',
#  'subject13',
#  'subject14',
#  'subject15',
#  'subject16',
#  'subject17',
#  'subject18',
#  'subject20',
#  'subject22',
#  'subject23',
#  'subject24',
#  'subject25',
#  'subject26',
#  'subject27',
#  'subject3',
#  'subject30',
#  'subject31',
#  'subject32',
#  'subject33',
#  'subject34',
#  'subject35',
#  'subject36',
#  'subject37',
#  'subject38',
#  'subject39',
#  'subject4',
#  'subject40',
#  'subject41',
#  'subject42',
#  'subject43',
#  'subject44',
#  'subject45',
#  'subject46',
#  'subject47',
#  'subject48',
#  'subject49',
#  'subject5',
#  'subject8',
#  'subject9']
